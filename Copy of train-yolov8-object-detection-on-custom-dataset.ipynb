# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## ⚠️ Disclaimer
#
# YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **03.01.2024** with version **YOLOv8.0.196**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on how to train YOLOv8 Object Detection, concurrently.
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu May 30 07:53:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **03.01.2024** with version **YOLOv8.0.196**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/78.2 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 121MB/s]
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 100MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 91.3ms
# Speed: 12.4ms preprocess, 91.3ms inference, 714.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 101.8ms
# Speed: 3.4ms preprocess, 101.8ms inference, 643.7ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.0000,  314.4717,  625.0754, 1278.1946],
#         [  55.1731,  250.0220,  648.1080, 1266.2720],
#         [ 633.2291,  719.5391,  701.0538,  786.0336]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.7271, 0.2907, 0.2846], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a supported format, the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v5 PyTorch` dataset format.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RTUa4wS9JImFKQ1CE5hj")
project = rf.workspace("internship-uhlzk").project("hard-hat-sample-mua3c")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# /content/datasets
# Collecting roboflow
#   Downloading roboflow-1.1.30-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 3.3 MB/s eta 0:00:00
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.7 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.0 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 10.2 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Installing collected packages: python-magic, python-dotenv, opencv-python-headless, idna, cycler, chardet, certifi, requests-toolbelt, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 python-dotenv-1.0.1 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.30
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Hard-Hat-Sample-2 to yolov8:: 100%|██████████| 6194/6194 [00:00<00:00, 16694.24it/s]
# Extracting Dataset Version Zip to Hard-Hat-Sample-2 in yolov8:: 100%|██████████| 491/491 [00:00<00:00, 8569.81it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=5 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 241MB/s]
# New https://pypi.org/project/ultralytics/8.2.25 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Hard-Hat-Sample-2/data.yaml, epochs=5, patience=50, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 21.3MB/s]
# 2024-05-30 08:10:07.480438: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 08:10:07.480498: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 08:10:07.482297: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, [128, 256, 512]]
# Model summary: 225 layers, 11136761 parameters, 11136745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# WARNING ⚠️ NMS time limit 0.550s exceeded
# AMP: checks passed ✅
# train: Scanning /content/datasets/Hard-Hat-Sample-2/train/labels... 210 images, 0 backgrounds, 0 corrupt: 100% 210/210 [00:00<00:00, 1740.87it/s]
# train: New cache created: /content/datasets/Hard-Hat-Sample-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/datasets/Hard-Hat-Sample-2/valid/labels... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<00:00, 1377.87it/s]
# val: New cache created: /content/datasets/Hard-Hat-Sample-2/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0% 0/14 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#         1/5      6.57G      2.271      3.969      2.111        117        800:  93% 13/14 [00:09<00:00,  2.13it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#         1/5      6.58G      2.264      3.957      2.136          3        800: 100% 14/14 [00:10<00:00,  1.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:02<00:00,  2.18s/it]
#                    all         20         65      0.668      0.374      0.315      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5      6.83G      1.629      1.929       1.54         12        800: 100% 14/14 [00:08<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.35it/s]
#                    all         20         65       0.88      0.437      0.518      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5      6.83G      1.497      1.521      1.443         18        800: 100% 14/14 [00:05<00:00,  2.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         20         65      0.833      0.462      0.485       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5       6.8G      1.427      1.422      1.406          3        800: 100% 14/14 [00:08<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.29it/s]
#                    all         20         65      0.921      0.523      0.564      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5      6.84G      1.354      1.221      1.333         10        800: 100% 14/14 [00:06<00:00,  2.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.41it/s]
#                    all         20         65      0.922      0.581      0.637      0.374
#
# 5 epochs completed in 0.015 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.50it/s]
#                    all         20         65      0.922      0.581      0.637      0.373
#                   head         20         18      0.833      0.831      0.826      0.494
#                 helmet         20         45      0.932      0.911      0.959      0.563
#                 person         20          2          1          0      0.124     0.0627
# Speed: 0.3ms preprocess, 6.7ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    labels.jpg	  train_batch0.jpg
# confusion_matrix_normalized.png			    P_curve.png   train_batch1.jpg
# confusion_matrix.png				    PR_curve.png  train_batch2.jpg
# events.out.tfevents.1717056610.9fe3c523af01.4812.0  R_curve.png   val_batch0_labels.jpg
# F1_curve.png					    results.csv   val_batch0_pred.jpg
# labels_correlogram.jpg				    results.png   weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Hard-Hat-Sample-2/valid/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.02it/s]
#                    all         20         65      0.922      0.581      0.636      0.373
#                   head         20         18      0.833      0.832      0.825      0.493
#                 helmet         20         45      0.932      0.911      0.959      0.564
#                 person         20          2          1          0      0.124     0.0627
# Speed: 0.4ms preprocess, 34.8ms inference, 0.0ms loss, 37.9ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/helmetdetection.mp4 save=True
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/5282) /content/helmetdetection.mp4: 480x800 4 heads, 4 helmets, 105.3ms
# video 1/1 (2/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 15.7ms
# video 1/1 (3/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 15.6ms
# video 1/1 (4/5282) /content/helmetdetection.mp4: 480x800 6 heads, 4 helmets, 15.6ms
# video 1/1 (5/5282) /content/helmetdetection.mp4: 480x800 4 heads, 4 helmets, 15.6ms
# video 1/1 (6/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 18.8ms
# video 1/1 (7/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 15.6ms
# video 1/1 (8/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 15.6ms
# video 1/1 (9/5282) /content/helmetdetection.mp4: 480x800 4 heads, 5 helmets, 15.6ms
# video 1/1 (10/5282) /content/helmetdetection.mp4: 480x800 6 heads, 4 helmets, 15.6ms
# video 1/1 (11/5282) /content/helmetdetection.mp4: 480x800 6 heads, 4 helmets, 15.6ms
# video 1/1 (12/5282) /content/helmetdetection.mp4: 480x800 7 heads, 4 helmets, 15.6ms
# video 1/1 (13/5282) /content/helmetdetection.mp4: 480x800 8 heads, 4 helmets, 15.6ms
# video 1/1 (14/5282) /content/helmetdetection.mp4: 480x800 7 heads, 4 helmets, 15.6ms
# video 1/1 (15/5282) /content/helmetdetection.mp4: 480x800 7 heads, 4 helmets, 15.6ms
# video 1/1 (16/5282) /content/helmetdetection.mp4: 480x800 8 heads, 4 helmets, 15.6ms
# video 1/1 (17/5282) /content/helmetdetection.mp4: 480x800 8 heads, 4 helmets, 16.1ms
# video 1/1 (18/5282) /content/helmetdetection.mp4: 480x800 7 heads, 4 helmets, 15.6ms
# video 1/1 (19/5282) /content/helmetdetection.mp4: 480x800 6 heads, 5 helmets, 17.6ms
# video 1/1 (20/5282) /content/helmetdetection.mp4: 480x800 6 heads, 5 helmets, 15.6ms
# video 1/1 (21/5282) /content/helmetdetection.mp4: 480x800 7 heads, 5 helmets, 15.6ms
# video 1/1 (22/5282) /content/helmetdetection.mp4: 480x800 9 heads, 5 helmets, 15.7ms
# video 1/1 (23/5282) /content/helmetdetection.mp4: 480x800 6 heads, 5 helmets, 15.6ms
# video 1/1 (24/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 15.6ms
# video 1/1 (25/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 15.6ms
# video 1/1 (26/5282) /content/helmetdetection.mp4: 480x800 7 heads, 7 helmets, 15.6ms
# video 1/1 (27/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 15.7ms
# video 1/1 (28/5282) /content/helmetdetection.mp4: 480x800 5 heads, 6 helmets, 15.6ms
# video 1/1 (29/5282) /content/helmetdetection.mp4: 480x800 8 heads, 5 helmets, 15.6ms
# video 1/1 (30/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 15.6ms
# video 1/1 (31/5282) /content/helmetdetection.mp4: 480x800 9 heads, 5 helmets, 15.6ms
# video 1/1 (32/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 15.6ms
# video 1/1 (33/5282) /content/helmetdetection.mp4: 480x800 11 heads, 6 helmets, 15.6ms
# video 1/1 (34/5282) /content/helmetdetection.mp4: 480x800 12 heads, 5 helmets, 17.9ms
# video 1/1 (35/5282) /content/helmetdetection.mp4: 480x800 10 heads, 6 helmets, 15.6ms
# video 1/1 (36/5282) /content/helmetdetection.mp4: 480x800 11 heads, 5 helmets, 15.6ms
# video 1/1 (37/5282) /content/helmetdetection.mp4: 480x800 10 heads, 5 helmets, 15.6ms
# video 1/1 (38/5282) /content/helmetdetection.mp4: 480x800 10 heads, 6 helmets, 15.6ms
# video 1/1 (39/5282) /content/helmetdetection.mp4: 480x800 9 heads, 5 helmets, 15.6ms
# video 1/1 (40/5282) /content/helmetdetection.mp4: 480x800 9 heads, 6 helmets, 15.6ms
# video 1/1 (41/5282) /content/helmetdetection.mp4: 480x800 9 heads, 6 helmets, 15.6ms
# video 1/1 (42/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 15.6ms
# video 1/1 (43/5282) /content/helmetdetection.mp4: 480x800 6 heads, 6 helmets, 15.6ms
# video 1/1 (44/5282) /content/helmetdetection.mp4: 480x800 6 heads, 6 helmets, 15.6ms
# video 1/1 (45/5282) /content/helmetdetection.mp4: 480x800 8 heads, 5 helmets, 15.6ms
# video 1/1 (46/5282) /content/helmetdetection.mp4: 480x800 10 heads, 5 helmets, 15.6ms
# video 1/1 (47/5282) /content/helmetdetection.mp4: 480x800 7 heads, 7 helmets, 15.6ms
# video 1/1 (48/5282) /content/helmetdetection.mp4: 480x800 9 heads, 7 helmets, 15.6ms
# video 1/1 (49/5282) /content/helmetdetection.mp4: 480x800 10 heads, 7 helmets, 15.6ms
# video 1/1 (50/5282) /content/helmetdetection.mp4: 480x800 10 heads, 7 helmets, 15.6ms
# video 1/1 (51/5282) /content/helmetdetection.mp4: 480x800 9 heads, 7 helmets, 15.6ms
# video 1/1 (52/5282) /content/helmetdetection.mp4: 480x800 11 heads, 7 helmets, 15.5ms
# video 1/1 (53/5282) /content/helmetdetection.mp4: 480x800 10 heads, 6 helmets, 15.0ms
# video 1/1 (54/5282) /content/helmetdetection.mp4: 480x800 9 heads, 6 helmets, 15.3ms
# video 1/1 (55/5282) /content/helmetdetection.mp4: 480x800 9 heads, 6 helmets, 14.9ms
# video 1/1 (56/5282) /content/helmetdetection.mp4: 480x800 9 heads, 7 helmets, 14.9ms
# video 1/1 (57/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 14.9ms
# video 1/1 (58/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 14.6ms
# video 1/1 (59/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 14.7ms
# video 1/1 (60/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 14.7ms
# video 1/1 (61/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 14.6ms
# video 1/1 (62/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 14.6ms
# video 1/1 (63/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 14.7ms
# video 1/1 (64/5282) /content/helmetdetection.mp4: 480x800 9 heads, 6 helmets, 14.6ms
# video 1/1 (65/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 14.6ms
# video 1/1 (66/5282) /content/helmetdetection.mp4: 480x800 8 heads, 8 helmets, 14.6ms
# video 1/1 (67/5282) /content/helmetdetection.mp4: 480x800 9 heads, 8 helmets, 14.6ms
# video 1/1 (68/5282) /content/helmetdetection.mp4: 480x800 8 heads, 8 helmets, 14.6ms
# video 1/1 (69/5282) /content/helmetdetection.mp4: 480x800 7 heads, 8 helmets, 14.6ms
# video 1/1 (70/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 14.6ms
# video 1/1 (71/5282) /content/helmetdetection.mp4: 480x800 7 heads, 8 helmets, 14.6ms
# video 1/1 (72/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 14.6ms
# video 1/1 (73/5282) /content/helmetdetection.mp4: 480x800 7 heads, 7 helmets, 14.5ms
# video 1/1 (74/5282) /content/helmetdetection.mp4: 480x800 5 heads, 6 helmets, 13.8ms
# video 1/1 (75/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 13.8ms
# video 1/1 (76/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 13.8ms
# video 1/1 (77/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 13.8ms
# video 1/1 (78/5282) /content/helmetdetection.mp4: 480x800 9 heads, 5 helmets, 13.8ms
# video 1/1 (79/5282) /content/helmetdetection.mp4: 480x800 12 heads, 5 helmets, 13.8ms
# video 1/1 (80/5282) /content/helmetdetection.mp4: 480x800 12 heads, 6 helmets, 13.8ms
# video 1/1 (81/5282) /content/helmetdetection.mp4: 480x800 10 heads, 6 helmets, 1 person, 13.8ms
# video 1/1 (82/5282) /content/helmetdetection.mp4: 480x800 10 heads, 6 helmets, 1 person, 13.8ms
# video 1/1 (83/5282) /content/helmetdetection.mp4: 480x800 10 heads, 6 helmets, 13.8ms
# video 1/1 (84/5282) /content/helmetdetection.mp4: 480x800 11 heads, 7 helmets, 1 person, 13.8ms
# video 1/1 (85/5282) /content/helmetdetection.mp4: 480x800 10 heads, 5 helmets, 1 person, 13.8ms
# video 1/1 (86/5282) /content/helmetdetection.mp4: 480x800 9 heads, 5 helmets, 13.8ms
# video 1/1 (87/5282) /content/helmetdetection.mp4: 480x800 7 heads, 5 helmets, 13.8ms
# video 1/1 (88/5282) /content/helmetdetection.mp4: 480x800 7 heads, 4 helmets, 1 person, 13.9ms
# video 1/1 (89/5282) /content/helmetdetection.mp4: 480x800 8 heads, 4 helmets, 1 person, 13.8ms
# video 1/1 (90/5282) /content/helmetdetection.mp4: 480x800 7 heads, 4 helmets, 1 person, 13.8ms
# video 1/1 (91/5282) /content/helmetdetection.mp4: 480x800 8 heads, 5 helmets, 1 person, 13.8ms
# video 1/1 (92/5282) /content/helmetdetection.mp4: 480x800 8 heads, 5 helmets, 13.8ms
# video 1/1 (93/5282) /content/helmetdetection.mp4: 480x800 10 heads, 7 helmets, 13.8ms
# video 1/1 (94/5282) /content/helmetdetection.mp4: 480x800 9 heads, 7 helmets, 13.8ms
# video 1/1 (95/5282) /content/helmetdetection.mp4: 480x800 6 heads, 9 helmets, 13.8ms
# video 1/1 (96/5282) /content/helmetdetection.mp4: 480x800 5 heads, 10 helmets, 13.8ms
# video 1/1 (97/5282) /content/helmetdetection.mp4: 480x800 5 heads, 10 helmets, 13.8ms
# video 1/1 (98/5282) /content/helmetdetection.mp4: 480x800 7 heads, 8 helmets, 13.8ms
# video 1/1 (99/5282) /content/helmetdetection.mp4: 480x800 5 heads, 8 helmets, 13.8ms
# video 1/1 (100/5282) /content/helmetdetection.mp4: 480x800 6 heads, 9 helmets, 13.8ms
# video 1/1 (101/5282) /content/helmetdetection.mp4: 480x800 5 heads, 9 helmets, 13.8ms
# video 1/1 (102/5282) /content/helmetdetection.mp4: 480x800 7 heads, 8 helmets, 13.8ms
# video 1/1 (103/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 13.8ms
# video 1/1 (104/5282) /content/helmetdetection.mp4: 480x800 7 heads, 6 helmets, 13.8ms
# video 1/1 (105/5282) /content/helmetdetection.mp4: 480x800 7 heads, 5 helmets, 14.1ms
# video 1/1 (106/5282) /content/helmetdetection.mp4: 480x800 8 heads, 6 helmets, 13.8ms
# video 1/1 (107/5282) /content/helmetdetection.mp4: 480x800 8 heads, 7 helmets, 13.8ms
# video 1/1 (108/5282) /content/helmetdetection.mp4: 480x800 9 heads, 5 helmets, 13.8ms
# video 1/1 (109/5282) /content/helmetdetection.mp4: 480x800 7 heads, 7 helmets, 13.8ms
# video 1/1 (110/5282) /content/helmetdetection.mp4: 480x800 6 heads, 8 helmets, 13.8ms
# video 1/1 (111/5282) /content/helmetdetection.mp4: 480x800 6 heads, 7 helmets, 13.8ms
# video 1/1 (112/5282) /content/helmetdetection.mp4: 480x800 6 heads, 7 helmets, 13.8ms
# video 1/1 (113/5282) /content/helmetdetection.mp4: 480x800 5 heads, 6 helmets, 13.8ms
# video 1/1 (114/5282) /content/helmetdetection.mp4: 480x800 6 heads, 6 helmets, 1 person, 13.9ms
# video 1/1 (115/5282) /content/helmetdetection.mp4: 480x800 7 heads, 9 helmets, 13.8ms
# video 1/1 (116/5282) /content/helmetdetection.mp4: 480x800 4 heads, 8 helmets, 13.6ms
# video 1/1 (117/5282) /content/helmetdetection.mp4: 480x800 6 heads, 7 helmets, 13.7ms
# video 1/1 (118/5282) /content/helmetdetection.mp4: 480x800 5 heads, 9 helmets, 13.5ms
# video 1/1 (119/5282) /content/helmetdetection.mp4: 480x800 7 heads, 5 helmets, 13.5ms
# video 1/1 (120/5282) /content/helmetdetection.mp4: 480x800 6 heads, 8 helmets, 13.5ms
# video 1/1 (121/5282) /content/helmetdetection.mp4: 480x800 7 heads, 8 helmets, 13.6ms
# video 1/1 (122/5282) /content/helmetdetection.mp4: 480x800 7 heads, 7 helmets, 13.5ms
# video 1/1 (123/5282) /content/helmetdetection.mp4: 480x800 8 heads, 8 helmets, 13.6ms
# video 1/1 (124/5282) /content/helmetdetection.mp4: 480x800 9 heads, 6 helmets, 13.6ms
# video 1/1 (125/5282) /content/helmetdetection.mp4: 480x800 7 heads, 7 helmets, 13.6ms
# video 1/1 (126/5282) /content/helmetdetection.mp4: 480x800 9 heads, 8 helmets, 13.5ms
# video 1/1 (127/5282) /content/helmetdetection.mp4: 480x800 9 heads, 8 helmets, 13.6ms
# video 1/1 (128/5282) /content/helmetdetection.mp4: 480x800 7 heads, 9 helmets, 13.6ms
# video 1/1 (129/5282) /content/helmetdetection.mp4: 480x800 7 heads, 9 helmets, 13.6ms
# video 1/1 (130/5282) /content/helmetdetection.mp4: 480x800 7 heads, 11 helmets, 13.6ms
# video 1/1 (131/5282) /content/helmetdetection.mp4: 480x800 8 heads, 9 helmets, 13.6ms
# video 1/1 (132/5282) /content/helmetdetection.mp4: 480x800 8 heads, 11 helmets, 13.6ms
# video 1/1 (133/5282) /content/helmetdetection.mp4: 480x800 9 heads, 10 helmets, 13.6ms
# video 1/1 (134/5282) /content/helmetdetection.mp4: 480x800 9 heads, 11 helmets, 13.6ms
# video 1/1 (135/5282) /content/helmetdetection.mp4: 480x800 7 heads, 11 helmets, 13.7ms
# video 1/1 (136/5282) /content/helmetdetection.mp4: 480x800 8 heads, 11 helmets, 13.6ms
# video 1/1 (137/5282) /content/helmetdetection.mp4: 480x800 9 heads, 13 helmets, 13.6ms
# video 1/1 (138/5282) /content/helmetdetection.mp4: 480x800 9 heads, 13 helmets, 13.6ms
# video 1/1 (139/5282) /content/helmetdetection.mp4: 480x800 9 heads, 12 helmets, 13.6ms
# video 1/1 (140/5282) /content/helmetdetection.mp4: 480x800 6 heads, 12 helmets, 13.5ms
# video 1/1 (141/5282) /content/helmetdetection.mp4: 480x800 7 heads, 13 helmets, 13.6ms
# video 1/1 (142/5282) /content/helmetdetection.mp4: 480x800 6 heads, 14 helmets, 1 person, 13.5ms
# video 1/1 (143/5282) /content/helmetdetection.mp4: 480x800 7 heads, 13 helmets, 1 person, 13.6ms
# video 1/1 (144/5282) /content/helmetdetection.mp4: 480x800 7 heads, 13 helmets, 1 person, 13.6ms
# video 1/1 (145/5282) /content/helmetdetection.mp4: 480x800 4 heads, 15 helmets, 1 person, 13.6ms
# video 1/1 (146/5282) /content/helmetdetection.mp4: 480x800 4 heads, 16 helmets, 1 person, 13.6ms
# video 1/1 (147/5282) /content/helmetdetection.mp4: 480x800 5 heads, 13 helmets, 1 person, 13.6ms
# video 1/1 (148/5282) /content/helmetdetection.mp4: 480x800 2 heads, 14 helmets, 1 person, 13.5ms
# video 1/1 (149/5282) /content/helmetdetection.mp4: 480x800 3 heads, 14 helmets, 1 person, 13.5ms
# video 1/1 (150/5282) /content/helmetdetection.mp4: 480x800 2 heads, 15 helmets, 1 person, 13.5ms
# video 1/1 (151/5282) /content/helmetdetection.mp4: 480x800 2 heads, 17 helmets, 1 person, 13.6ms
# video 1/1 (152/5282) /content/helmetdetection.mp4: 480x800 2 heads, 13 helmets, 1 person, 13.5ms
# video 1/1 (153/5282) /content/helmetdetection.mp4: 480x800 3 heads, 13 helmets, 13.5ms
# video 1/1 (154/5282) /content/helmetdetection.mp4: 480x800 1 head, 12 helmets, 13.6ms
# video 1/1 (155/5282) /content/helmetdetection.mp4: 480x800 1 head, 12 helmets, 1 person, 13.5ms
# video 1/1 (156/5282) /content/helmetdetection.mp4: 480x800 1 head, 9 helmets, 1 person, 13.5ms
# video 1/1 (157/5282) /content/helmetdetection.mp4: 480x800 1 head, 10 helmets, 1 person, 13.6ms
# video 1/1 (158/5282) /content/helmetdetection.mp4: 480x800 1 head, 9 helmets, 13.5ms
# video 1/1 (159/5282) /content/helmetdetection.mp4: 480x800 2 heads, 10 helmets, 14.2ms
# video 1/1 (160/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 13.5ms
# video 1/1 (161/5282) /content/helmetdetection.mp4: 480x800 2 heads, 11 helmets, 13.5ms
# video 1/1 (162/5282) /content/helmetdetection.mp4: 480x800 2 heads, 13 helmets, 13.5ms
# video 1/1 (163/5282) /content/helmetdetection.mp4: 480x800 3 heads, 11 helmets, 12.9ms
# video 1/1 (164/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 12.9ms
# video 1/1 (165/5282) /content/helmetdetection.mp4: 480x800 3 heads, 12 helmets, 12.9ms
# video 1/1 (166/5282) /content/helmetdetection.mp4: 480x800 3 heads, 15 helmets, 12.9ms
# video 1/1 (167/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 12.9ms
# video 1/1 (168/5282) /content/helmetdetection.mp4: 480x800 1 head, 12 helmets, 12.9ms
# video 1/1 (169/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 12.9ms
# video 1/1 (170/5282) /content/helmetdetection.mp4: 480x800 1 head, 9 helmets, 13.0ms
# video 1/1 (171/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 12.9ms
# video 1/1 (172/5282) /content/helmetdetection.mp4: 480x800 1 head, 10 helmets, 12.9ms
# video 1/1 (173/5282) /content/helmetdetection.mp4: 480x800 1 head, 10 helmets, 12.9ms
# video 1/1 (174/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 12.9ms
# video 1/1 (175/5282) /content/helmetdetection.mp4: 480x800 1 head, 18 helmets, 12.9ms
# video 1/1 (176/5282) /content/helmetdetection.mp4: 480x800 2 heads, 16 helmets, 12.9ms
# video 1/1 (177/5282) /content/helmetdetection.mp4: 480x800 2 heads, 18 helmets, 12.9ms
# video 1/1 (178/5282) /content/helmetdetection.mp4: 480x800 1 head, 14 helmets, 12.9ms
# video 1/1 (179/5282) /content/helmetdetection.mp4: 480x800 1 head, 13 helmets, 12.9ms
# video 1/1 (180/5282) /content/helmetdetection.mp4: 480x800 1 head, 14 helmets, 12.9ms
# video 1/1 (181/5282) /content/helmetdetection.mp4: 480x800 1 head, 13 helmets, 12.9ms
# video 1/1 (182/5282) /content/helmetdetection.mp4: 480x800 1 head, 16 helmets, 12.8ms
# video 1/1 (183/5282) /content/helmetdetection.mp4: 480x800 1 head, 14 helmets, 12.9ms
# video 1/1 (184/5282) /content/helmetdetection.mp4: 480x800 3 heads, 15 helmets, 12.9ms
# video 1/1 (185/5282) /content/helmetdetection.mp4: 480x800 3 heads, 13 helmets, 12.9ms
# video 1/1 (186/5282) /content/helmetdetection.mp4: 480x800 2 heads, 11 helmets, 12.9ms
# video 1/1 (187/5282) /content/helmetdetection.mp4: 480x800 1 head, 13 helmets, 12.8ms
# video 1/1 (188/5282) /content/helmetdetection.mp4: 480x800 2 heads, 18 helmets, 12.9ms
# video 1/1 (189/5282) /content/helmetdetection.mp4: 480x800 2 heads, 15 helmets, 12.9ms
# video 1/1 (190/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 12.9ms
# video 1/1 (191/5282) /content/helmetdetection.mp4: 480x800 1 head, 9 helmets, 12.9ms
# video 1/1 (192/5282) /content/helmetdetection.mp4: 480x800 8 helmets, 12.9ms
# video 1/1 (193/5282) /content/helmetdetection.mp4: 480x800 8 helmets, 12.9ms
# video 1/1 (194/5282) /content/helmetdetection.mp4: 480x800 1 head, 8 helmets, 12.9ms
# video 1/1 (195/5282) /content/helmetdetection.mp4: 480x800 1 head, 10 helmets, 12.9ms
# video 1/1 (196/5282) /content/helmetdetection.mp4: 480x800 1 head, 11 helmets, 12.9ms
# video 1/1 (197/5282) /content/helmetdetection.mp4: 480x800 2 heads, 10 helmets, 12.9ms
# video 1/1 (198/5282) /content/helmetdetection.mp4: 480x800 1 head, 8 helmets, 12.9ms
# video 1/1 (199/5282) /content/helmetdetection.mp4: 480x800 2 heads, 8 helmets, 12.9ms
# video 1/1 (200/5282) /content/helmetdetection.mp4: 480x800 4 heads, 6 helmets, 12.8ms
# video 1/1 (201/5282) /content/helmetdetection.mp4: 480x800 1 head, 10 helmets, 12.9ms
# video 1/1 (202/5282) /content/helmetdetection.mp4: 480x800 3 heads, 9 helmets, 12.9ms
# video 1/1 (203/5282) /content/helmetdetection.mp4: 480x800 3 heads, 9 helmets, 12.9ms
# video 1/1 (204/5282) /content/helmetdetection.mp4: 480x800 4 heads, 8 helmets, 12.9ms
# video 1/1 (205/5282) /content/helmetdetection.mp4: 480x800 4 heads, 8 helmets, 12.8ms
# video 1/1 (206/5282) /content/helmetdetection.mp4: 480x800 2 heads, 9 helmets, 12.9ms
# video 1/1 (207/5282) /content/helmetdetection.mp4: 480x800 3 heads, 7 helmets, 12.9ms
# video 1/1 (208/5282) /content/helmetdetection.mp4: 480x800 3 heads, 9 helmets, 12.9ms
# video 1/1 (209/5282) /content/helmetdetection.mp4: 480x800 3 heads, 9 helmets, 12.9ms
# video 1/1 (210/5282) /content/helmetdetection.mp4: 480x800 3 heads, 8 helmets, 12.9ms
# video 1/1 (211/5282) /content/helmetdetection.mp4: 480x800 3 heads, 8 helmets, 12.9ms
# video 1/1 (212/5282) /content/helmetdetection.mp4: 480x800 3 heads, 7 helmets, 12.8ms
# video 1/1 (213/5282) /content/helmetdetection.mp4: 480x800 4 heads, 9 helmets, 12.9ms
# video 1/1 (214/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 12.9ms
# video 1/1 (215/5282) /content/helmetdetection.mp4: 480x800 4 heads, 5 helmets, 12.9ms
# video 1/1 (216/5282) /content/helmetdetection.mp4: 480x800 4 heads, 6 helmets, 12.9ms
# video 1/1 (217/5282) /content/helmetdetection.mp4: 480x800 4 heads, 8 helmets, 12.9ms
# video 1/1 (218/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 12.8ms
# video 1/1 (219/5282) /content/helmetdetection.mp4: 480x800 2 heads, 7 helmets, 12.9ms
# video 1/1 (220/5282) /content/helmetdetection.mp4: 480x800 2 heads, 6 helmets, 12.9ms
# video 1/1 (221/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.9ms
# video 1/1 (222/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (223/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.9ms
# video 1/1 (224/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (225/5282) /content/helmetdetection.mp4: 480x800 2 heads, 3 helmets, 12.9ms
# video 1/1 (226/5282) /content/helmetdetection.mp4: 480x800 3 heads, 3 helmets, 12.9ms
# video 1/1 (227/5282) /content/helmetdetection.mp4: 480x800 3 heads, 3 helmets, 12.9ms
# video 1/1 (228/5282) /content/helmetdetection.mp4: 480x800 3 heads, 3 helmets, 12.9ms
# video 1/1 (229/5282) /content/helmetdetection.mp4: 480x800 4 heads, 2 helmets, 12.9ms
# video 1/1 (230/5282) /content/helmetdetection.mp4: 480x800 6 heads, 4 helmets, 12.8ms
# video 1/1 (231/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 12.9ms
# video 1/1 (232/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 12.8ms
# video 1/1 (233/5282) /content/helmetdetection.mp4: 480x800 6 heads, 9 helmets, 12.9ms
# video 1/1 (234/5282) /content/helmetdetection.mp4: 480x800 5 heads, 6 helmets, 12.9ms
# video 1/1 (235/5282) /content/helmetdetection.mp4: 480x800 5 heads, 8 helmets, 12.8ms
# video 1/1 (236/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 12.9ms
# video 1/1 (237/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 13.0ms
# video 1/1 (238/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 12.9ms
# video 1/1 (239/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 12.9ms
# video 1/1 (240/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 12.8ms
# video 1/1 (241/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 12.8ms
# video 1/1 (242/5282) /content/helmetdetection.mp4: 480x800 6 heads, 5 helmets, 12.9ms
# video 1/1 (243/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 12.8ms
# video 1/1 (244/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 12.9ms
# video 1/1 (245/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 12.8ms
# video 1/1 (246/5282) /content/helmetdetection.mp4: 480x800 5 heads, 7 helmets, 12.9ms
# video 1/1 (247/5282) /content/helmetdetection.mp4: 480x800 5 heads, 6 helmets, 12.8ms
# video 1/1 (248/5282) /content/helmetdetection.mp4: 480x800 5 heads, 5 helmets, 12.9ms
# video 1/1 (249/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 12.9ms
# video 1/1 (250/5282) /content/helmetdetection.mp4: 480x800 6 heads, 3 helmets, 12.8ms
# video 1/1 (251/5282) /content/helmetdetection.mp4: 480x800 5 heads, 3 helmets, 12.9ms
# video 1/1 (252/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 12.9ms
# video 1/1 (253/5282) /content/helmetdetection.mp4: 480x800 5 heads, 4 helmets, 12.9ms
# video 1/1 (254/5282) /content/helmetdetection.mp4: 480x800 5 heads, 3 helmets, 12.9ms
# video 1/1 (255/5282) /content/helmetdetection.mp4: 480x800 5 heads, 3 helmets, 12.9ms
# video 1/1 (256/5282) /content/helmetdetection.mp4: 480x800 5 heads, 3 helmets, 12.9ms
# video 1/1 (257/5282) /content/helmetdetection.mp4: 480x800 7 heads, 3 helmets, 12.9ms
# video 1/1 (258/5282) /content/helmetdetection.mp4: 480x800 6 heads, 4 helmets, 12.8ms
# video 1/1 (259/5282) /content/helmetdetection.mp4: 480x800 7 heads, 5 helmets, 12.8ms
# video 1/1 (260/5282) /content/helmetdetection.mp4: 480x800 7 heads, 5 helmets, 12.9ms
# video 1/1 (261/5282) /content/helmetdetection.mp4: 480x800 6 heads, 5 helmets, 12.8ms
# video 1/1 (262/5282) /content/helmetdetection.mp4: 480x800 6 heads, 5 helmets, 12.9ms
# video 1/1 (263/5282) /content/helmetdetection.mp4: 480x800 6 heads, 3 helmets, 12.9ms
# video 1/1 (264/5282) /content/helmetdetection.mp4: 480x800 6 heads, 3 helmets, 12.8ms
# video 1/1 (265/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.9ms
# video 1/1 (266/5282) /content/helmetdetection.mp4: 480x800 6 heads, 3 helmets, 12.9ms
# video 1/1 (267/5282) /content/helmetdetection.mp4: 480x800 7 heads, 3 helmets, 12.9ms
# video 1/1 (268/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.8ms
# video 1/1 (269/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.9ms
# video 1/1 (270/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.9ms
# video 1/1 (271/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.8ms
# video 1/1 (272/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.8ms
# video 1/1 (273/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.9ms
# video 1/1 (274/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.8ms
# video 1/1 (275/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.8ms
# video 1/1 (276/5282) /content/helmetdetection.mp4: 480x800 6 heads, 3 helmets, 12.8ms
# video 1/1 (277/5282) /content/helmetdetection.mp4: 480x800 6 heads, 3 helmets, 12.8ms
# video 1/1 (278/5282) /content/helmetdetection.mp4: 480x800 6 heads, 3 helmets, 12.8ms
# video 1/1 (279/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.8ms
# video 1/1 (280/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.9ms
# video 1/1 (281/5282) /content/helmetdetection.mp4: 480x800 6 heads, 2 helmets, 12.9ms
# video 1/1 (282/5282) /content/helmetdetection.mp4: 480x800 8 heads, 26 helmets, 12.9ms
# video 1/1 (283/5282) /content/helmetdetection.mp4: 480x800 8 heads, 28 helmets, 12.9ms
# video 1/1 (284/5282) /content/helmetdetection.mp4: 480x800 8 heads, 26 helmets, 12.8ms
# video 1/1 (285/5282) /content/helmetdetection.mp4: 480x800 7 heads, 28 helmets, 12.8ms
# video 1/1 (286/5282) /content/helmetdetection.mp4: 480x800 7 heads, 25 helmets, 12.9ms
# video 1/1 (287/5282) /content/helmetdetection.mp4: 480x800 8 heads, 29 helmets, 12.9ms
# video 1/1 (288/5282) /content/helmetdetection.mp4: 480x800 7 heads, 27 helmets, 12.9ms
# video 1/1 (289/5282) /content/helmetdetection.mp4: 480x800 6 heads, 25 helmets, 13.1ms
# video 1/1 (290/5282) /content/helmetdetection.mp4: 480x800 6 heads, 26 helmets, 13.1ms
# video 1/1 (291/5282) /content/helmetdetection.mp4: 480x800 7 heads, 25 helmets, 13.1ms
# video 1/1 (292/5282) /content/helmetdetection.mp4: 480x800 7 heads, 25 helmets, 13.1ms
# video 1/1 (293/5282) /content/helmetdetection.mp4: 480x800 8 heads, 24 helmets, 13.3ms
# video 1/1 (294/5282) /content/helmetdetection.mp4: 480x800 5 heads, 26 helmets, 13.3ms
# video 1/1 (295/5282) /content/helmetdetection.mp4: 480x800 6 heads, 26 helmets, 13.4ms
# video 1/1 (296/5282) /content/helmetdetection.mp4: 480x800 6 heads, 26 helmets, 13.3ms
# video 1/1 (297/5282) /content/helmetdetection.mp4: 480x800 6 heads, 29 helmets, 13.3ms
# video 1/1 (298/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 13.6ms
# video 1/1 (299/5282) /content/helmetdetection.mp4: 480x800 6 heads, 30 helmets, 13.5ms
# video 1/1 (300/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 13.5ms
# video 1/1 (301/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 13.5ms
# video 1/1 (302/5282) /content/helmetdetection.mp4: 480x800 6 heads, 26 helmets, 13.8ms
# video 1/1 (303/5282) /content/helmetdetection.mp4: 480x800 6 heads, 25 helmets, 13.9ms
# video 1/1 (304/5282) /content/helmetdetection.mp4: 480x800 5 heads, 25 helmets, 13.9ms
# video 1/1 (305/5282) /content/helmetdetection.mp4: 480x800 8 heads, 28 helmets, 13.9ms
# video 1/1 (306/5282) /content/helmetdetection.mp4: 480x800 6 heads, 27 helmets, 14.1ms
# video 1/1 (307/5282) /content/helmetdetection.mp4: 480x800 5 heads, 27 helmets, 14.1ms
# video 1/1 (308/5282) /content/helmetdetection.mp4: 480x800 5 heads, 27 helmets, 14.1ms
# video 1/1 (309/5282) /content/helmetdetection.mp4: 480x800 6 heads, 25 helmets, 14.1ms
# video 1/1 (310/5282) /content/helmetdetection.mp4: 480x800 7 heads, 26 helmets, 14.3ms
# video 1/1 (311/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 14.3ms
# video 1/1 (312/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 14.3ms
# video 1/1 (313/5282) /content/helmetdetection.mp4: 480x800 8 heads, 30 helmets, 14.3ms
# video 1/1 (314/5282) /content/helmetdetection.mp4: 480x800 8 heads, 27 helmets, 14.7ms
# video 1/1 (315/5282) /content/helmetdetection.mp4: 480x800 8 heads, 28 helmets, 14.7ms
# video 1/1 (316/5282) /content/helmetdetection.mp4: 480x800 8 heads, 26 helmets, 14.7ms
# video 1/1 (317/5282) /content/helmetdetection.mp4: 480x800 9 heads, 25 helmets, 15.0ms
# video 1/1 (318/5282) /content/helmetdetection.mp4: 480x800 9 heads, 24 helmets, 14.9ms
# video 1/1 (319/5282) /content/helmetdetection.mp4: 480x800 8 heads, 25 helmets, 15.0ms
# video 1/1 (320/5282) /content/helmetdetection.mp4: 480x800 7 heads, 25 helmets, 15.6ms
# video 1/1 (321/5282) /content/helmetdetection.mp4: 480x800 6 heads, 25 helmets, 15.6ms
# video 1/1 (322/5282) /content/helmetdetection.mp4: 480x800 5 heads, 23 helmets, 15.6ms
# video 1/1 (323/5282) /content/helmetdetection.mp4: 480x800 5 heads, 24 helmets, 15.6ms
# video 1/1 (324/5282) /content/helmetdetection.mp4: 480x800 5 heads, 26 helmets, 15.6ms
# video 1/1 (325/5282) /content/helmetdetection.mp4: 480x800 5 heads, 26 helmets, 18.1ms
# video 1/1 (326/5282) /content/helmetdetection.mp4: 480x800 9 heads, 27 helmets, 15.6ms
# video 1/1 (327/5282) /content/helmetdetection.mp4: 480x800 10 heads, 26 helmets, 15.6ms
# video 1/1 (328/5282) /content/helmetdetection.mp4: 480x800 9 heads, 25 helmets, 15.6ms
# video 1/1 (329/5282) /content/helmetdetection.mp4: 480x800 8 heads, 26 helmets, 15.6ms
# video 1/1 (330/5282) /content/helmetdetection.mp4: 480x800 9 heads, 27 helmets, 15.6ms
# video 1/1 (331/5282) /content/helmetdetection.mp4: 480x800 8 heads, 30 helmets, 15.6ms
# video 1/1 (332/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 15.6ms
# video 1/1 (333/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 15.6ms
# video 1/1 (334/5282) /content/helmetdetection.mp4: 480x800 5 heads, 28 helmets, 15.6ms
# video 1/1 (335/5282) /content/helmetdetection.mp4: 480x800 5 heads, 29 helmets, 15.6ms
# video 1/1 (336/5282) /content/helmetdetection.mp4: 480x800 5 heads, 27 helmets, 15.6ms
# video 1/1 (337/5282) /content/helmetdetection.mp4: 480x800 4 heads, 28 helmets, 15.6ms
# video 1/1 (338/5282) /content/helmetdetection.mp4: 480x800 4 heads, 25 helmets, 18.9ms
# video 1/1 (339/5282) /content/helmetdetection.mp4: 480x800 4 heads, 25 helmets, 16.4ms
# video 1/1 (340/5282) /content/helmetdetection.mp4: 480x800 4 heads, 24 helmets, 16.9ms
# video 1/1 (341/5282) /content/helmetdetection.mp4: 480x800 6 heads, 26 helmets, 15.7ms
# video 1/1 (342/5282) /content/helmetdetection.mp4: 480x800 5 heads, 28 helmets, 15.6ms
# video 1/1 (343/5282) /content/helmetdetection.mp4: 480x800 5 heads, 25 helmets, 15.6ms
# video 1/1 (344/5282) /content/helmetdetection.mp4: 480x800 5 heads, 27 helmets, 15.6ms
# video 1/1 (345/5282) /content/helmetdetection.mp4: 480x800 7 heads, 26 helmets, 20.7ms
# video 1/1 (346/5282) /content/helmetdetection.mp4: 480x800 7 heads, 27 helmets, 15.6ms
# video 1/1 (347/5282) /content/helmetdetection.mp4: 480x800 7 heads, 26 helmets, 15.6ms
# video 1/1 (348/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (349/5282) /content/helmetdetection.mp4: 480x800 6 heads, 27 helmets, 15.6ms
# video 1/1 (350/5282) /content/helmetdetection.mp4: 480x800 5 heads, 30 helmets, 15.6ms
# video 1/1 (351/5282) /content/helmetdetection.mp4: 480x800 6 heads, 30 helmets, 15.6ms
# video 1/1 (352/5282) /content/helmetdetection.mp4: 480x800 6 heads, 30 helmets, 15.7ms
# video 1/1 (353/5282) /content/helmetdetection.mp4: 480x800 5 heads, 29 helmets, 15.7ms
# video 1/1 (354/5282) /content/helmetdetection.mp4: 480x800 5 heads, 29 helmets, 15.6ms
# video 1/1 (355/5282) /content/helmetdetection.mp4: 480x800 5 heads, 30 helmets, 15.6ms
# video 1/1 (356/5282) /content/helmetdetection.mp4: 480x800 6 heads, 31 helmets, 15.6ms
# video 1/1 (357/5282) /content/helmetdetection.mp4: 480x800 5 heads, 31 helmets, 15.6ms
# video 1/1 (358/5282) /content/helmetdetection.mp4: 480x800 5 heads, 31 helmets, 15.6ms
# video 1/1 (359/5282) /content/helmetdetection.mp4: 480x800 6 heads, 31 helmets, 15.5ms
# video 1/1 (360/5282) /content/helmetdetection.mp4: 480x800 5 heads, 31 helmets, 15.5ms
# video 1/1 (361/5282) /content/helmetdetection.mp4: 480x800 6 heads, 30 helmets, 15.5ms
# video 1/1 (362/5282) /content/helmetdetection.mp4: 480x800 8 heads, 29 helmets, 15.6ms
# video 1/1 (363/5282) /content/helmetdetection.mp4: 480x800 8 heads, 28 helmets, 15.6ms
# video 1/1 (364/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (365/5282) /content/helmetdetection.mp4: 480x800 6 heads, 30 helmets, 15.6ms
# video 1/1 (366/5282) /content/helmetdetection.mp4: 480x800 8 heads, 29 helmets, 15.5ms
# video 1/1 (367/5282) /content/helmetdetection.mp4: 480x800 7 heads, 31 helmets, 15.6ms
# video 1/1 (368/5282) /content/helmetdetection.mp4: 480x800 7 heads, 30 helmets, 15.5ms
# video 1/1 (369/5282) /content/helmetdetection.mp4: 480x800 7 heads, 31 helmets, 15.6ms
# video 1/1 (370/5282) /content/helmetdetection.mp4: 480x800 6 heads, 29 helmets, 15.6ms
# video 1/1 (371/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (372/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (373/5282) /content/helmetdetection.mp4: 480x800 7 heads, 30 helmets, 15.6ms
# video 1/1 (374/5282) /content/helmetdetection.mp4: 480x800 7 heads, 28 helmets, 15.6ms
# video 1/1 (375/5282) /content/helmetdetection.mp4: 480x800 7 heads, 30 helmets, 15.6ms
# video 1/1 (376/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (377/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (378/5282) /content/helmetdetection.mp4: 480x800 7 heads, 31 helmets, 15.5ms
# video 1/1 (379/5282) /content/helmetdetection.mp4: 480x800 6 heads, 30 helmets, 15.5ms
# video 1/1 (380/5282) /content/helmetdetection.mp4: 480x800 8 heads, 28 helmets, 15.5ms
# video 1/1 (381/5282) /content/helmetdetection.mp4: 480x800 8 heads, 29 helmets, 15.5ms
# video 1/1 (382/5282) /content/helmetdetection.mp4: 480x800 8 heads, 29 helmets, 15.6ms
# video 1/1 (383/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (384/5282) /content/helmetdetection.mp4: 480x800 6 heads, 31 helmets, 15.6ms
# video 1/1 (385/5282) /content/helmetdetection.mp4: 480x800 7 heads, 31 helmets, 15.6ms
# video 1/1 (386/5282) /content/helmetdetection.mp4: 480x800 6 heads, 29 helmets, 15.6ms
# video 1/1 (387/5282) /content/helmetdetection.mp4: 480x800 6 heads, 27 helmets, 15.6ms
# video 1/1 (388/5282) /content/helmetdetection.mp4: 480x800 7 heads, 26 helmets, 15.6ms
# video 1/1 (389/5282) /content/helmetdetection.mp4: 480x800 6 heads, 26 helmets, 15.6ms
# video 1/1 (390/5282) /content/helmetdetection.mp4: 480x800 6 heads, 27 helmets, 15.6ms
# video 1/1 (391/5282) /content/helmetdetection.mp4: 480x800 7 heads, 31 helmets, 15.6ms
# video 1/1 (392/5282) /content/helmetdetection.mp4: 480x800 7 heads, 32 helmets, 15.6ms
# video 1/1 (393/5282) /content/helmetdetection.mp4: 480x800 6 heads, 30 helmets, 15.6ms
# video 1/1 (394/5282) /content/helmetdetection.mp4: 480x800 7 heads, 30 helmets, 15.6ms
# video 1/1 (395/5282) /content/helmetdetection.mp4: 480x800 7 heads, 31 helmets, 15.6ms
# video 1/1 (396/5282) /content/helmetdetection.mp4: 480x800 7 heads, 28 helmets, 15.6ms
# video 1/1 (397/5282) /content/helmetdetection.mp4: 480x800 8 heads, 29 helmets, 15.6ms
# video 1/1 (398/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (399/5282) /content/helmetdetection.mp4: 480x800 7 heads, 28 helmets, 15.5ms
# video 1/1 (400/5282) /content/helmetdetection.mp4: 480x800 7 heads, 26 helmets, 15.5ms
# video 1/1 (401/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (402/5282) /content/helmetdetection.mp4: 480x800 7 heads, 27 helmets, 15.6ms
# video 1/1 (403/5282) /content/helmetdetection.mp4: 480x800 7 heads, 28 helmets, 15.6ms
# video 1/1 (404/5282) /content/helmetdetection.mp4: 480x800 8 heads, 28 helmets, 15.6ms
# video 1/1 (405/5282) /content/helmetdetection.mp4: 480x800 10 heads, 29 helmets, 15.6ms
# video 1/1 (406/5282) /content/helmetdetection.mp4: 480x800 13 heads, 29 helmets, 15.6ms
# video 1/1 (407/5282) /content/helmetdetection.mp4: 480x800 10 heads, 27 helmets, 15.6ms
# video 1/1 (408/5282) /content/helmetdetection.mp4: 480x800 12 heads, 27 helmets, 15.5ms
# video 1/1 (409/5282) /content/helmetdetection.mp4: 480x800 11 heads, 26 helmets, 15.5ms
# video 1/1 (410/5282) /content/helmetdetection.mp4: 480x800 8 heads, 27 helmets, 15.6ms
# video 1/1 (411/5282) /content/helmetdetection.mp4: 480x800 7 heads, 28 helmets, 15.6ms
# video 1/1 (412/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 15.6ms
# video 1/1 (413/5282) /content/helmetdetection.mp4: 480x800 7 heads, 29 helmets, 15.6ms
# video 1/1 (414/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 15.6ms
# video 1/1 (415/5282) /content/helmetdetection.mp4: 480x800 6 heads, 28 helmets, 15.5ms
# video 1/1 (416/5282) /content/helmetdetection.mp4: 480x800 6 heads, 25 helmets, 15.6ms
# video 1/1 (417/5282) /content/helmetdetection.mp4: 480x800 6 heads, 23 helmets, 15.6ms
# video 1/1 (418/5282) /content/helmetdetection.mp4: 480x800 6 heads, 25 helmets, 15.6ms
# video 1/1 (419/5282) /content/helmetdetection.mp4: 480x800 7 heads, 25 helmets, 17.2ms
# video 1/1 (420/5282) /content/helmetdetection.mp4: 480x800 8 heads, 25 helmets, 15.6ms
# video 1/1 (421/5282) /content/helmetdetection.mp4: 480x800 9 heads, 27 helmets, 15.6ms
# video 1/1 (422/5282) /content/helmetdetection.mp4: 480x800 8 heads, 26 helmets, 15.7ms
# video 1/1 (423/5282) /content/helmetdetection.mp4: 480x800 7 heads, 26 helmets, 15.7ms
# video 1/1 (424/5282) /content/helmetdetection.mp4: 480x800 7 heads, 26 helmets, 15.6ms
# video 1/1 (425/5282) /content/helmetdetection.mp4: 480x800 9 heads, 24 helmets, 15.6ms
# video 1/1 (426/5282) /content/helmetdetection.mp4: 480x800 6 heads, 23 helmets, 15.6ms
# video 1/1 (427/5282) /content/helmetdetection.mp4: 480x800 7 heads, 24 helmets, 15.6ms
# video 1/1 (428/5282) /content/helmetdetection.mp4: 480x800 8 heads, 22 helmets, 15.6ms
# video 1/1 (429/5282) /content/helmetdetection.mp4: 480x800 7 heads, 24 helmets, 15.6ms
# video 1/1 (430/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 16.3ms
# video 1/1 (431/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 16.5ms
# video 1/1 (432/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.6ms
# video 1/1 (433/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.6ms
# video 1/1 (434/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.6ms
# video 1/1 (435/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.6ms
# video 1/1 (436/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.6ms
# video 1/1 (437/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.5ms
# video 1/1 (438/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.6ms
# video 1/1 (439/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.6ms
# video 1/1 (440/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.5ms
# video 1/1 (441/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 16.7ms
# video 1/1 (442/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.5ms
# video 1/1 (443/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.6ms
# video 1/1 (444/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.6ms
# video 1/1 (445/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.6ms
# video 1/1 (446/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.5ms
# video 1/1 (447/5282) /content/helmetdetection.mp4: 480x800 5 heads, 10 helmets, 15.6ms
# video 1/1 (448/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# video 1/1 (449/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (450/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (451/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (452/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (453/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (454/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (455/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (456/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (457/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.2ms
# video 1/1 (458/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.2ms
# video 1/1 (459/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (460/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.2ms
# video 1/1 (461/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (462/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (463/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (464/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (465/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (466/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (467/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.2ms
# video 1/1 (468/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.5ms
# video 1/1 (469/5282) /content/helmetdetection.mp4: 480x800 4 heads, 13 helmets, 15.3ms
# video 1/1 (470/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.3ms
# video 1/1 (471/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.3ms
# video 1/1 (472/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.3ms
# video 1/1 (473/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.3ms
# video 1/1 (474/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (475/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.3ms
# video 1/1 (476/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (477/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.3ms
# video 1/1 (478/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (479/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.2ms
# video 1/1 (480/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (481/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (482/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (483/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (484/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (485/5282) /content/helmetdetection.mp4: 480x800 5 heads, 11 helmets, 15.2ms
# video 1/1 (486/5282) /content/helmetdetection.mp4: 480x800 5 heads, 11 helmets, 15.2ms
# video 1/1 (487/5282) /content/helmetdetection.mp4: 480x800 5 heads, 11 helmets, 14.9ms
# video 1/1 (488/5282) /content/helmetdetection.mp4: 480x800 5 heads, 11 helmets, 14.9ms
# video 1/1 (489/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (490/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (491/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (492/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (493/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (494/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (495/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (496/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (497/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (498/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (499/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 14.9ms
# video 1/1 (500/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (501/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (502/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (503/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (504/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (505/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (506/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (507/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (508/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (509/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (510/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (511/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (512/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (513/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (514/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (515/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (516/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.0ms
# video 1/1 (517/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (518/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (519/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 14.9ms
# video 1/1 (520/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 14.9ms
# video 1/1 (521/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (522/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (523/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (524/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (525/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (526/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (527/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (528/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 15.0ms
# video 1/1 (529/5282) /content/helmetdetection.mp4: 480x800 4 heads, 12 helmets, 14.9ms
# video 1/1 (530/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 14.9ms
# video 1/1 (531/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.3ms
# video 1/1 (532/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (533/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (534/5282) /content/helmetdetection.mp4: 480x800 4 heads, 11 helmets, 15.2ms
# video 1/1 (535/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (536/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (537/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# video 1/1 (538/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (539/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# video 1/1 (540/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# video 1/1 (541/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# video 1/1 (542/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# video 1/1 (543/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (544/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (545/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (546/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (547/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (548/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# video 1/1 (549/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.2ms
# video 1/1 (550/5282) /content/helmetdetection.mp4: 480x800 4 heads, 10 helmets, 15.3ms
# ...
# video 1/1 (1529/5282) /content/helmetdetection.mp4: 480x800 2 heads, 3 helmets, 13.3ms
# video 1/1 (1530/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 13.5ms
# video 1/1 (1531/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 13.5ms
# video 1/1 (1532/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 13.5ms
# video 1/1 (1533/5282) /content/helmetdetection.mp4: 480x800 2 heads, 3 helmets, 13.6ms
# video 1/1 (1534/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 13.5ms
# video 1/1 (1535/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 18.1ms
# video 1/1 (1536/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 13.5ms
# video 1/1 (1537/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 13.6ms
# video 1/1 (1538/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 13.6ms
# video 1/1 (1539/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 14.9ms
# video 1/1 (1540/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 14.1ms
# video 1/1 (1541/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 14.1ms
# video 1/1 (1542/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 14.1ms
# video 1/1 (1543/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 14.2ms
# video 1/1 (1544/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 14.3ms
# video 1/1 (1545/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 14.4ms
# video 1/1 (1546/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 14.8ms
# video 1/1 (1547/5282) /content/helmetdetection.mp4: 480x800 1 head, 7 helmets, 14.4ms
# video 1/1 (1548/5282) /content/helmetdetection.mp4: 480x800 1 head, 7 helmets, 14.5ms
# video 1/1 (1549/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 14.4ms
# video 1/1 (1550/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 14.4ms
# video 1/1 (1551/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 14.4ms
# video 1/1 (1552/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 15.5ms
# video 1/1 (1553/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 14.6ms
# video 1/1 (1554/5282) /content/helmetdetection.mp4: 480x800 1 head, 7 helmets, 14.6ms
# video 1/1 (1555/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 14.6ms
# video 1/1 (1556/5282) /content/helmetdetection.mp4: 480x800 6 helmets, 14.9ms
# video 1/1 (1557/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 14.9ms
# video 1/1 (1558/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 14.9ms
# video 1/1 (1559/5282) /content/helmetdetection.mp4: 480x800 7 helmets, 14.9ms
# video 1/1 (1560/5282) /content/helmetdetection.mp4: 480x800 6 helmets, 15.3ms
# video 1/1 (1561/5282) /content/helmetdetection.mp4: 480x800 6 helmets, 15.3ms
# video 1/1 (1562/5282) /content/helmetdetection.mp4: 480x800 7 helmets, 15.3ms
# video 1/1 (1563/5282) /content/helmetdetection.mp4: 480x800 8 helmets, 15.3ms
# video 1/1 (1564/5282) /content/helmetdetection.mp4: 480x800 6 helmets, 15.2ms
# video 1/1 (1565/5282) /content/helmetdetection.mp4: 480x800 6 helmets, 15.3ms
# video 1/1 (1566/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 18.0ms
# video 1/1 (1567/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 15.3ms
# video 1/1 (1568/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 15.6ms
# video 1/1 (1569/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 15.5ms
# video 1/1 (1570/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 15.6ms
# video 1/1 (1571/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 15.6ms
# video 1/1 (1572/5282) /content/helmetdetection.mp4: 480x800 8 helmets, 15.6ms
# video 1/1 (1573/5282) /content/helmetdetection.mp4: 480x800 7 helmets, 15.6ms
# video 1/1 (1574/5282) /content/helmetdetection.mp4: 480x800 7 helmets, 15.6ms
# video 1/1 (1575/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 15.5ms
# video 1/1 (1576/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 15.6ms
# video 1/1 (1577/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 15.6ms
# video 1/1 (1578/5282) /content/helmetdetection.mp4: 480x800 6 helmets, 15.3ms
# video 1/1 (1579/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 1 person, 14.3ms
# video 1/1 (1580/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 14.3ms
# video 1/1 (1581/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 14.3ms
# video 1/1 (1582/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 14.3ms
# video 1/1 (1583/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 14.4ms
# video 1/1 (1584/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 14.1ms
# video 1/1 (1585/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 14.1ms
# video 1/1 (1586/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 14.1ms
# video 1/1 (1587/5282) /content/helmetdetection.mp4: 480x800 3 heads, 6 helmets, 14.1ms
# video 1/1 (1588/5282) /content/helmetdetection.mp4: 480x800 4 heads, 5 helmets, 14.1ms
# video 1/1 (1589/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 14.1ms
# video 1/1 (1590/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 14.2ms
# video 1/1 (1591/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 14.1ms
# video 1/1 (1592/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 14.1ms
# video 1/1 (1593/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 14.1ms
# video 1/1 (1594/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 15.7ms
# video 1/1 (1595/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 13.7ms
# video 1/1 (1596/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 13.5ms
# video 1/1 (1597/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 13.6ms
# video 1/1 (1598/5282) /content/helmetdetection.mp4: 480x800 1 head, 7 helmets, 13.6ms
# video 1/1 (1599/5282) /content/helmetdetection.mp4: 480x800 4 heads, 8 helmets, 13.7ms
# video 1/1 (1600/5282) /content/helmetdetection.mp4: 480x800 1 head, 8 helmets, 13.6ms
# video 1/1 (1601/5282) /content/helmetdetection.mp4: 480x800 1 head, 8 helmets, 13.5ms
# video 1/1 (1602/5282) /content/helmetdetection.mp4: 480x800 1 head, 9 helmets, 13.5ms
# video 1/1 (1603/5282) /content/helmetdetection.mp4: 480x800 8 helmets, 1 person, 13.5ms
# video 1/1 (1604/5282) /content/helmetdetection.mp4: 480x800 1 head, 10 helmets, 13.5ms
# video 1/1 (1605/5282) /content/helmetdetection.mp4: 480x800 3 heads, 7 helmets, 13.5ms
# video 1/1 (1606/5282) /content/helmetdetection.mp4: 480x800 8 helmets, 13.7ms
# video 1/1 (1607/5282) /content/helmetdetection.mp4: 480x800 1 head, 9 helmets, 13.6ms
# video 1/1 (1608/5282) /content/helmetdetection.mp4: 480x800 7 helmets, 13.6ms
# video 1/1 (1609/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 1 person, 13.6ms
# video 1/1 (1610/5282) /content/helmetdetection.mp4: 480x800 5 helmets, 1 person, 13.6ms
# video 1/1 (1611/5282) /content/helmetdetection.mp4: 480x800 7 helmets, 13.5ms
# video 1/1 (1612/5282) /content/helmetdetection.mp4: 480x800 6 helmets, 13.5ms
# video 1/1 (1613/5282) /content/helmetdetection.mp4: 480x800 3 helmets, 13.6ms
# video 1/1 (1614/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 13.5ms
# video 1/1 (1615/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 13.6ms
# video 1/1 (1616/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 13.5ms
# video 1/1 (1617/5282) /content/helmetdetection.mp4: 480x800 3 heads, 5 helmets, 12.9ms
# video 1/1 (1618/5282) /content/helmetdetection.mp4: 480x800 3 heads, 4 helmets, 12.8ms
# video 1/1 (1619/5282) /content/helmetdetection.mp4: 480x800 3 heads, 3 helmets, 12.9ms
# video 1/1 (1620/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (1621/5282) /content/helmetdetection.mp4: 480x800 3 heads, 3 helmets, 12.9ms
# video 1/1 (1622/5282) /content/helmetdetection.mp4: 480x800 3 heads, 7 helmets, 12.9ms
# video 1/1 (1623/5282) /content/helmetdetection.mp4: 480x800 2 heads, 6 helmets, 12.9ms
# video 1/1 (1624/5282) /content/helmetdetection.mp4: 480x800 3 heads, 7 helmets, 12.9ms
# video 1/1 (1625/5282) /content/helmetdetection.mp4: 480x800 4 heads, 4 helmets, 12.8ms
# video 1/1 (1626/5282) /content/helmetdetection.mp4: 480x800 4 heads, 4 helmets, 12.9ms
# video 1/1 (1627/5282) /content/helmetdetection.mp4: 480x800 3 heads, 8 helmets, 12.9ms
# video 1/1 (1628/5282) /content/helmetdetection.mp4: 480x800 4 heads, 4 helmets, 12.9ms
# video 1/1 (1629/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (1630/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (1631/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.9ms
# video 1/1 (1632/5282) /content/helmetdetection.mp4: 480x800 2 heads, 7 helmets, 12.8ms
# video 1/1 (1633/5282) /content/helmetdetection.mp4: 480x800 3 heads, 4 helmets, 12.9ms
# video 1/1 (1634/5282) /content/helmetdetection.mp4: 480x800 4 heads, 5 helmets, 1 person, 12.8ms
# video 1/1 (1635/5282) /content/helmetdetection.mp4: 480x800 3 heads, 4 helmets, 1 person, 12.9ms
# video 1/1 (1636/5282) /content/helmetdetection.mp4: 480x800 3 heads, 4 helmets, 1 person, 12.8ms
# video 1/1 (1637/5282) /content/helmetdetection.mp4: 480x800 3 heads, 4 helmets, 12.9ms
# video 1/1 (1638/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (1639/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 1 person, 12.9ms
# video 1/1 (1640/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 1 person, 12.9ms
# video 1/1 (1641/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 2 persons, 12.9ms
# video 1/1 (1642/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1643/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1644/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.8ms
# video 1/1 (1645/5282) /content/helmetdetection.mp4: 480x800 2 heads, 3 helmets, 12.9ms
# video 1/1 (1646/5282) /content/helmetdetection.mp4: 480x800 2 heads, 3 helmets, 12.8ms
# video 1/1 (1647/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.9ms
# video 1/1 (1648/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 12.9ms
# video 1/1 (1649/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 12.9ms
# video 1/1 (1650/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (1651/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.9ms
# video 1/1 (1652/5282) /content/helmetdetection.mp4: 480x800 2 heads, 3 helmets, 12.9ms
# video 1/1 (1653/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.9ms
# video 1/1 (1654/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.8ms
# video 1/1 (1655/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 13.5ms
# video 1/1 (1656/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.8ms
# video 1/1 (1657/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.8ms
# video 1/1 (1658/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1659/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1660/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1661/5282) /content/helmetdetection.mp4: 480x800 1 head, 6 helmets, 12.9ms
# video 1/1 (1662/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.9ms
# video 1/1 (1663/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 14.2ms
# video 1/1 (1664/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.8ms
# video 1/1 (1665/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1666/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.8ms
# video 1/1 (1667/5282) /content/helmetdetection.mp4: 480x800 2 heads, 2 helmets, 12.9ms
# video 1/1 (1668/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.8ms
# video 1/1 (1669/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.9ms
# video 1/1 (1670/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.9ms
# video 1/1 (1671/5282) /content/helmetdetection.mp4: 480x800 3 helmets, 12.9ms
# video 1/1 (1672/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 12.9ms
# video 1/1 (1673/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 13.5ms
# video 1/1 (1674/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 12.9ms
# video 1/1 (1675/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 12.9ms
# video 1/1 (1676/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 14.8ms
# video 1/1 (1677/5282) /content/helmetdetection.mp4: 480x800 2 heads, 5 helmets, 12.9ms
# video 1/1 (1678/5282) /content/helmetdetection.mp4: 480x800 2 heads, 6 helmets, 12.9ms
# video 1/1 (1679/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1680/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.9ms
# video 1/1 (1681/5282) /content/helmetdetection.mp4: 480x800 2 heads, 2 helmets, 12.9ms
# video 1/1 (1682/5282) /content/helmetdetection.mp4: 480x800 3 heads, 3 helmets, 12.9ms
# video 1/1 (1683/5282) /content/helmetdetection.mp4: 480x800 2 heads, 3 helmets, 12.9ms
# video 1/1 (1684/5282) /content/helmetdetection.mp4: 480x800 2 heads, 2 helmets, 12.9ms
# video 1/1 (1685/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.9ms
# video 1/1 (1686/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1687/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 12.9ms
# video 1/1 (1688/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 12.8ms
# video 1/1 (1689/5282) /content/helmetdetection.mp4: 480x800 3 helmets, 12.9ms
# video 1/1 (1690/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 12.9ms
# video 1/1 (1691/5282) /content/helmetdetection.mp4: 480x800 3 helmets, 12.9ms
# video 1/1 (1692/5282) /content/helmetdetection.mp4: 480x800 4 helmets, 12.9ms
# video 1/1 (1693/5282) /content/helmetdetection.mp4: 480x800 1 head, 5 helmets, 12.9ms
# video 1/1 (1694/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1695/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.9ms
# video 1/1 (1696/5282) /content/helmetdetection.mp4: 480x800 2 heads, 4 helmets, 12.9ms
# video 1/1 (1697/5282) /content/helmetdetection.mp4: 480x800 1 head, 4 helmets, 12.9ms
# video 1/1 (1698/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.7ms
# video 1/1 (1699/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.6ms
# video 1/1 (1700/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.7ms
# video 1/1 (1701/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.6ms
# video 1/1 (1702/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.7ms
# video 1/1 (1703/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.7ms
# video 1/1 (1704/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.6ms
# video 1/1 (1705/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.6ms
# video 1/1 (1706/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.6ms
# video 1/1 (1707/5282) /content/helmetdetection.mp4: 480x800 1 head, 3 helmets, 12.7ms
# video 1/1 (1708/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.7ms
# [NULL @ 0x5b39e4821e40] Invalid NAL unit size (14541 > 8954).
# [NULL @ 0x5b39e4821e40] missing picture in access unit with size 8958
# [h264 @ 0x5b39eb18c0c0] Invalid NAL unit size (14541 > 8954).
# [h264 @ 0x5b39eb18c0c0] Error splitting the input into NAL units.
# video 1/1 (1709/5282) /content/helmetdetection.mp4: 480x800 1 head, 2 helmets, 12.6ms
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5b39e4822c40] stream 0, offset 0xe015d3: partial file
# Speed: 3.8ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict3/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/1
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/1

# %%
#While your deployment is processing, checkout the deployment docs to take your model to most destinations https://docs.roboflow.com/inference

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
